# %% [markdown]
# # Model 5
#
# Eight layer deep model, with sigmoid activation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, MaxPooling1D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
# Out:
# Using TensorFlow backend.
# /Users/bmmorris/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
from glob import glob

# %%
X = []
labels = []

for lcpath, truthpath in zip(sorted(glob('../data/parallel_normed/*_simulated_transit_lcs.npy')), 
                             sorted(glob('../data/parallel_normed/*_simulated_spots_occulted.npy'))):
    X.append(np.load(lcpath).T)
    labels.append(np.load(truthpath))

X = np.concatenate(X)[:, :, np.newaxis]# - np.array(X).mean()
X -= X.mean()
X /= X.ptp()
# X += 0.5
labels = np.hstack(labels)#[:, np.newaxis]

# %%
for x, l in zip(X[:100, :], labels):
    plt.plot(x, color='r' if l else 'b', alpha=0.5)

# %%
# X = np.random.randn(*X.shape)

# %%
# X = np.load('data/simulated_transit_lcs.npy')[:, :, np.newaxis]
# labels = np.load('data/simulated_spots_occulted.npy').astype(int)#[:, np.newaxis]

# %%
train_X = X
train_Y = labels

print('Training data shape : ', train_X.shape, train_Y.shape)

# print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (12000, 50, 1) (12000,)

# %%
# Find the unique numbers from the train labels
classes = np.unique(train_Y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  2
# Output classes :  [False  True]

# %%
train_X = train_X.astype('float32')

# %%
from keras.utils import to_categorical

train_Y_one_hot = to_categorical(train_Y)

# %%
from sklearn.model_selection import train_test_split

train_X, valid_X, train_label, valid_label = train_test_split(train_X, train_Y_one_hot, 
                                                              test_size=0.2, random_state=13)

# %%
alpha = 0.1
kernel_size = 5
activation = 'sigmoid'
padding = 'same'
dropout_rate = 0.25

batch_size = 128 #64
epochs = 50
num_classes = 2

model = Sequential()

# First layer
model.add(Conv1D(filters=32, kernel_size=kernel_size, activation=activation, 
                 input_shape=(train_X.shape[1], 1), padding=padding))
model.add(LeakyReLU(alpha=alpha))
model.add(MaxPooling1D(2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# Second layer
model.add(Conv1D(filters=64, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# Third layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# fourth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# fifth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# sixth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# seventh layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# eighth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# Fully connected layer 1
model.add(Flatten())
model.add(Dense(128, activation=activation))
model.add(LeakyReLU(alpha=alpha))

# Fully connected layer 2
# model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy, 
              optimizer=keras.optimizers.Adam(),
#               optimizer=keras.optimizers.SGD(lr=1e-4),
              metrics=['accuracy'])
model.summary()
# model.load_weights('data/weights.hdf5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 50, 32)            192
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 50, 32)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 25, 32)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 25, 32)            128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 25, 64)            10304
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 25, 64)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 13, 64)            0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 64)            256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 13, 128)           41088
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 13, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 7, 128)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 128)            512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 128)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 7, 128)            82048
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 128)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 128)            512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 128)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 4, 128)            82048
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 4, 128)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 2, 128)            0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 128)            512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 128)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 2, 128)            82048
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 2, 128)            0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1, 128)            82048
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1, 128)            0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1, 128)            82048
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1, 128)            0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 482,050
# Trainable params: 480,322
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
train = model.fit(train_X, train_label, batch_size=batch_size, 
                  epochs=epochs, validation_data=(valid_X, valid_label))
# Out:
# Train on 9600 samples, validate on 2400 samples
# Epoch 1/50
# 9600/9600 [==============================] - 7s 718us/step - loss: 0.3965 - acc: 0.8208 - val_loss: 0.4645 - val_acc: 0.8804
# Epoch 2/50
# 9600/9600 [==============================] - 4s 387us/step - loss: 0.2544 - acc: 0.9026 - val_loss: 0.1912 - val_acc: 0.9363
# Epoch 3/50
# 9600/9600 [==============================] - 4s 372us/step - loss: 0.2229 - acc: 0.9211 - val_loss: 0.4515 - val_acc: 0.8367
# Epoch 4/50
# 9600/9600 [==============================] - 4s 366us/step - loss: 0.2080 - acc: 0.9260 - val_loss: 0.1600 - val_acc: 0.9492
# Epoch 5/50
# 9600/9600 [==============================] - 3s 354us/step - loss: 0.2034 - acc: 0.9264 - val_loss: 0.1681 - val_acc: 0.9446
# Epoch 6/50
# 9600/9600 [==============================] - 3s 361us/step - loss: 0.1893 - acc: 0.9354 - val_loss: 0.1535 - val_acc: 0.9487
# Epoch 7/50
# 9600/9600 [==============================] - 3s 351us/step - loss: 0.1837 - acc: 0.9364 - val_loss: 0.1513 - val_acc: 0.9500
# Epoch 8/50
# 9600/9600 [==============================] - 3s 361us/step - loss: 0.1804 - acc: 0.9389 - val_loss: 0.1504 - val_acc: 0.9471
# Epoch 9/50
# 9600/9600 [==============================] - 3s 359us/step - loss: 0.1749 - acc: 0.9393 - val_loss: 0.2587 - val_acc: 0.9242
# Epoch 10/50
# 9600/9600 [==============================] - 3s 347us/step - loss: 0.1789 - acc: 0.9382 - val_loss: 0.2864 - val_acc: 0.9117
# Epoch 11/50
# 9600/9600 [==============================] - 4s 376us/step - loss: 0.1605 - acc: 0.9428 - val_loss: 0.1782 - val_acc: 0.9358
# Epoch 12/50
# 9600/9600 [==============================] - 5s 470us/step - loss: 0.1604 - acc: 0.9450 - val_loss: 0.1959 - val_acc: 0.9312
# Epoch 13/50
# 9600/9600 [==============================] - 4s 443us/step - loss: 0.1604 - acc: 0.9445 - val_loss: 0.1739 - val_acc: 0.9396
# Epoch 14/50
# 9600/9600 [==============================] - 4s 420us/step - loss: 0.1565 - acc: 0.9455 - val_loss: 0.1981 - val_acc: 0.9375
# Epoch 15/50
# 9600/9600 [==============================] - 4s 387us/step - loss: 0.1538 - acc: 0.9472 - val_loss: 0.2029 - val_acc: 0.9367
# Epoch 16/50
# 9600/9600 [==============================] - 4s 388us/step - loss: 0.1480 - acc: 0.9493 - val_loss: 0.1308 - val_acc: 0.9554
# Epoch 17/50
# 9600/9600 [==============================] - 4s 382us/step - loss: 0.1454 - acc: 0.9530 - val_loss: 0.1369 - val_acc: 0.9567
# Epoch 18/50
# 9600/9600 [==============================] - 4s 401us/step - loss: 0.1533 - acc: 0.9488 - val_loss: 0.3165 - val_acc: 0.9133
# Epoch 19/50
# 9600/9600 [==============================] - 4s 407us/step - loss: 0.1513 - acc: 0.9508 - val_loss: 0.1868 - val_acc: 0.9363
# Epoch 20/50
# 9600/9600 [==============================] - 4s 404us/step - loss: 0.1441 - acc: 0.9522 - val_loss: 0.1511 - val_acc: 0.9513
# Epoch 21/50
# 9600/9600 [==============================] - 4s 421us/step - loss: 0.1499 - acc: 0.9484 - val_loss: 0.1758 - val_acc: 0.9429
# Epoch 22/50
# 9600/9600 [==============================] - 4s 417us/step - loss: 0.1478 - acc: 0.9510 - val_loss: 0.1723 - val_acc: 0.9408
# Epoch 23/50
# 9600/9600 [==============================] - 4s 419us/step - loss: 0.1508 - acc: 0.9460 - val_loss: 0.1508 - val_acc: 0.9471
# Epoch 24/50
# 9600/9600 [==============================] - 4s 401us/step - loss: 0.1405 - acc: 0.9544 - val_loss: 0.1314 - val_acc: 0.9600
# Epoch 25/50
# 9600/9600 [==============================] - 4s 412us/step - loss: 0.1392 - acc: 0.9526 - val_loss: 0.1345 - val_acc: 0.9550
# Epoch 26/50
# 9600/9600 [==============================] - 4s 376us/step - loss: 0.1366 - acc: 0.9529 - val_loss: 0.1701 - val_acc: 0.9462
# Epoch 27/50
# 9600/9600 [==============================] - 4s 368us/step - loss: 0.1348 - acc: 0.9576 - val_loss: 0.1247 - val_acc: 0.9596
# Epoch 28/50
# 9600/9600 [==============================] - 4s 401us/step - loss: 0.1322 - acc: 0.9568 - val_loss: 0.1995 - val_acc: 0.9350
# Epoch 29/50
# 9600/9600 [==============================] - 4s 419us/step - loss: 0.1310 - acc: 0.9547 - val_loss: 0.1367 - val_acc: 0.9533
# Epoch 30/50
# 9600/9600 [==============================] - 4s 463us/step - loss: 0.1358 - acc: 0.9533 - val_loss: 0.1253 - val_acc: 0.9579
# Epoch 31/50
# 9600/9600 [==============================] - 4s 422us/step - loss: 0.1287 - acc: 0.9551 - val_loss: 0.1338 - val_acc: 0.9575
# Epoch 32/50
# 9600/9600 [==============================] - 4s 404us/step - loss: 0.1270 - acc: 0.9554 - val_loss: 0.1411 - val_acc: 0.9550
# Epoch 33/50
# 9600/9600 [==============================] - 4s 462us/step - loss: 0.1331 - acc: 0.9541 - val_loss: 0.1327 - val_acc: 0.9542
# Epoch 34/50
# 9600/9600 [==============================] - 5s 545us/step - loss: 0.1339 - acc: 0.9552 - val_loss: 0.1343 - val_acc: 0.9571
# Epoch 35/50
# 9600/9600 [==============================] - 6s 635us/step - loss: 0.1266 - acc: 0.9580 - val_loss: 0.1360 - val_acc: 0.9550
# Epoch 36/50
# 9600/9600 [==============================] - 6s 644us/step - loss: 0.1261 - acc: 0.9576 - val_loss: 0.1435 - val_acc: 0.9558
# Epoch 37/50
# 9600/9600 [==============================] - 6s 669us/step - loss: 0.1308 - acc: 0.9571 - val_loss: 0.1402 - val_acc: 0.9525
# Epoch 38/50
# 9600/9600 [==============================] - 7s 693us/step - loss: 0.1226 - acc: 0.9584 - val_loss: 0.1196 - val_acc: 0.9642
# Epoch 39/50
# 9600/9600 [==============================] - 6s 662us/step - loss: 0.1302 - acc: 0.9566 - val_loss: 0.1215 - val_acc: 0.9571
# Epoch 40/50
# 9600/9600 [==============================] - 7s 714us/step - loss: 0.1168 - acc: 0.9615 - val_loss: 0.1268 - val_acc: 0.9579
# Epoch 41/50
# 9600/9600 [==============================] - 7s 715us/step - loss: 0.1243 - acc: 0.9585 - val_loss: 0.1320 - val_acc: 0.9579
# Epoch 42/50
# 9600/9600 [==============================] - 7s 731us/step - loss: 0.1201 - acc: 0.9597 - val_loss: 0.1290 - val_acc: 0.9600
# Epoch 43/50
# 9600/9600 [==============================] - 7s 758us/step - loss: 0.1261 - acc: 0.9584 - val_loss: 0.1511 - val_acc: 0.9492
# Epoch 44/50
# 9600/9600 [==============================] - 7s 689us/step - loss: 0.1185 - acc: 0.9613 - val_loss: 0.1279 - val_acc: 0.9563
# Epoch 45/50
# 9600/9600 [==============================] - 7s 697us/step - loss: 0.1202 - acc: 0.9603 - val_loss: 0.1654 - val_acc: 0.9496
# Epoch 46/50
# 9600/9600 [==============================] - 7s 707us/step - loss: 0.1190 - acc: 0.9608 - val_loss: 0.1934 - val_acc: 0.9462
# Epoch 47/50
# 9600/9600 [==============================] - 6s 646us/step - loss: 0.1204 - acc: 0.9603 - val_loss: 0.1485 - val_acc: 0.9542
# Epoch 48/50
# 9600/9600 [==============================] - 6s 648us/step - loss: 0.1224 - acc: 0.9594 - val_loss: 0.1199 - val_acc: 0.9604
# Epoch 49/50
# 9600/9600 [==============================] - 7s 714us/step - loss: 0.1195 - acc: 0.9609 - val_loss: 0.1587 - val_acc: 0.9492
# Epoch 50/50
# 9600/9600 [==============================] - 7s 678us/step - loss: 0.1164 - acc: 0.9610 - val_loss: 0.1193 - val_acc: 0.9600

# %%
accuracy = train.history['acc']
val_accuracy = train.history['val_acc']
loss = train.history['loss']
val_loss = train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model.save('data/model5.hdf5')
