# %% [markdown]
# # Model 6
#
# Eight layer deep model, with SGD optimizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, MaxPooling1D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
# Out:
# Using TensorFlow backend.
# /Users/bmmorris/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
from glob import glob

# %%
X = []
labels = []

for lcpath, truthpath in zip(sorted(glob('../data/parallel_normed/*_simulated_transit_lcs.npy')), 
                             sorted(glob('../data/parallel_normed/*_simulated_spots_occulted.npy'))):
    X.append(np.load(lcpath).T)
    labels.append(np.load(truthpath))

X = np.concatenate(X)[:, :, np.newaxis]# - np.array(X).mean()
X -= X.mean()
X /= X.ptp()
# X += 0.5
labels = np.hstack(labels)#[:, np.newaxis]

# %%
for x, l in zip(X[:100, :], labels):
    plt.plot(x, color='r' if l else 'b', alpha=0.5)

# %%
# X = np.random.randn(*X.shape)

# %%
# X = np.load('data/simulated_transit_lcs.npy')[:, :, np.newaxis]
# labels = np.load('data/simulated_spots_occulted.npy').astype(int)#[:, np.newaxis]

# %%
train_X = X
train_Y = labels

print('Training data shape : ', train_X.shape, train_Y.shape)

# print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (12000, 50, 1) (12000,)

# %%
# Find the unique numbers from the train labels
classes = np.unique(train_Y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  2
# Output classes :  [False  True]

# %%
train_X = train_X.astype('float32')

# %%
from keras.utils import to_categorical

train_Y_one_hot = to_categorical(train_Y)

# %%
from sklearn.model_selection import train_test_split

train_X, valid_X, train_label, valid_label = train_test_split(train_X, train_Y_one_hot, 
                                                              test_size=0.2, random_state=13)

# %%
alpha = 0.1
kernel_size = 5
activation = 'sigmoid'
padding = 'same'
dropout_rate = 0.25

batch_size = 128 #64
epochs = 50
num_classes = 2

model = Sequential()

# First layer
model.add(Conv1D(filters=32, kernel_size=kernel_size, activation=activation, 
                 input_shape=(train_X.shape[1], 1), padding=padding))
model.add(LeakyReLU(alpha=alpha))
model.add(MaxPooling1D(2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# Second layer
model.add(Conv1D(filters=64, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# Third layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# fourth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))

# fifth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# sixth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# seventh layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# eighth layer
model.add(Conv1D(filters=128, kernel_size=kernel_size, 
                 activation=activation, padding=padding))
model.add(LeakyReLU(alpha=alpha))                  
model.add(MaxPooling1D(pool_size=2, padding=padding))
model.add(BatchNormalization())
model.add(Dropout(dropout_rate))


# Fully connected layer 1
model.add(Flatten())
model.add(Dense(128, activation=activation))
model.add(LeakyReLU(alpha=alpha))

# Fully connected layer 2
# model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy, 
#               optimizer=keras.optimizers.Adam(),
              optimizer=keras.optimizers.SGD(),
              metrics=['accuracy'])
model.summary()
# model.load_weights('data/weights.hdf5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 50, 32)            192
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 50, 32)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 25, 32)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 25, 32)            128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 25, 64)            10304
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 25, 64)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 13, 64)            0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 64)            256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 13, 128)           41088
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 13, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 7, 128)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 128)            512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 128)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 7, 128)            82048
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 128)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 128)            512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 128)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 4, 128)            82048
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 4, 128)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 2, 128)            0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 128)            512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 128)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 2, 128)            82048
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 2, 128)            0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1, 128)            82048
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1, 128)            0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1, 128)            82048
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1, 128)            0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 482,050
# Trainable params: 480,322
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
train = model.fit(train_X, train_label, batch_size=batch_size, 
                  epochs=epochs, validation_data=(valid_X, valid_label))
# Out:
# Train on 9600 samples, validate on 2400 samples
# Epoch 1/50
# 9600/9600 [==============================] - 11s 1ms/step - loss: 0.6482 - acc: 0.6161 - val_loss: 1.0095 - val_acc: 0.5717
# Epoch 2/50
# 9600/9600 [==============================] - 6s 627us/step - loss: 0.5417 - acc: 0.7307 - val_loss: 1.2615 - val_acc: 0.6217
# Epoch 3/50
# 9600/9600 [==============================] - 6s 645us/step - loss: 0.4694 - acc: 0.7822 - val_loss: 1.2352 - val_acc: 0.6658
# Epoch 4/50
# 9600/9600 [==============================] - 7s 684us/step - loss: 0.4217 - acc: 0.8159 - val_loss: 1.0910 - val_acc: 0.7062
# Epoch 5/50
# 9600/9600 [==============================] - 6s 657us/step - loss: 0.3810 - acc: 0.8376 - val_loss: 0.9418 - val_acc: 0.7512
# Epoch 6/50
# 9600/9600 [==============================] - 7s 679us/step - loss: 0.3655 - acc: 0.8468 - val_loss: 0.8419 - val_acc: 0.7750
# Epoch 7/50
# 9600/9600 [==============================] - 7s 716us/step - loss: 0.3379 - acc: 0.8607 - val_loss: 0.7540 - val_acc: 0.7896
# Epoch 8/50
# 9600/9600 [==============================] - 7s 721us/step - loss: 0.3250 - acc: 0.8643 - val_loss: 0.6807 - val_acc: 0.8154
# Epoch 9/50
# 9600/9600 [==============================] - 7s 715us/step - loss: 0.3066 - acc: 0.8776 - val_loss: 0.6073 - val_acc: 0.8313
# Epoch 10/50
# 9600/9600 [==============================] - 7s 727us/step - loss: 0.2981 - acc: 0.8831 - val_loss: 0.5811 - val_acc: 0.8367
# Epoch 11/50
# 9600/9600 [==============================] - 6s 662us/step - loss: 0.2861 - acc: 0.8897 - val_loss: 0.5651 - val_acc: 0.8450
# Epoch 12/50
# 9600/9600 [==============================] - 7s 705us/step - loss: 0.2781 - acc: 0.8936 - val_loss: 0.5503 - val_acc: 0.8483
# Epoch 13/50
# 9600/9600 [==============================] - 6s 657us/step - loss: 0.2715 - acc: 0.8965 - val_loss: 0.4922 - val_acc: 0.8617
# Epoch 14/50
# 9600/9600 [==============================] - 6s 618us/step - loss: 0.2646 - acc: 0.9003 - val_loss: 0.4501 - val_acc: 0.8696
# Epoch 15/50
# 9600/9600 [==============================] - 6s 675us/step - loss: 0.2547 - acc: 0.9038 - val_loss: 0.4131 - val_acc: 0.8792
# Epoch 16/50
# 9600/9600 [==============================] - 7s 690us/step - loss: 0.2534 - acc: 0.9050 - val_loss: 0.4087 - val_acc: 0.8833
# Epoch 17/50
# 9600/9600 [==============================] - 6s 589us/step - loss: 0.2448 - acc: 0.9053 - val_loss: 0.3883 - val_acc: 0.8888
# Epoch 18/50
# 9600/9600 [==============================] - 4s 420us/step - loss: 0.2409 - acc: 0.9102 - val_loss: 0.3324 - val_acc: 0.8996
# Epoch 19/50
# 9600/9600 [==============================] - 4s 449us/step - loss: 0.2355 - acc: 0.9111 - val_loss: 0.3465 - val_acc: 0.8992
# Epoch 20/50
# 9600/9600 [==============================] - 5s 473us/step - loss: 0.2281 - acc: 0.9154 - val_loss: 0.3552 - val_acc: 0.8996
# Epoch 21/50
# 9600/9600 [==============================] - 4s 447us/step - loss: 0.2376 - acc: 0.9122 - val_loss: 0.3304 - val_acc: 0.9029
# Epoch 22/50
# 9600/9600 [==============================] - 5s 474us/step - loss: 0.2265 - acc: 0.9155 - val_loss: 0.3046 - val_acc: 0.9079
# Epoch 23/50
# 9600/9600 [==============================] - 5s 475us/step - loss: 0.2229 - acc: 0.9193 - val_loss: 0.3110 - val_acc: 0.9075
# Epoch 24/50
# 9600/9600 [==============================] - 4s 465us/step - loss: 0.2218 - acc: 0.9203 - val_loss: 0.3082 - val_acc: 0.9104
# Epoch 25/50
# 9600/9600 [==============================] - 5s 488us/step - loss: 0.2168 - acc: 0.9210 - val_loss: 0.2979 - val_acc: 0.9125
# Epoch 26/50
# 9600/9600 [==============================] - 4s 442us/step - loss: 0.2145 - acc: 0.9226 - val_loss: 0.3040 - val_acc: 0.9121
# Epoch 27/50
# 9600/9600 [==============================] - 4s 466us/step - loss: 0.2157 - acc: 0.9218 - val_loss: 0.3121 - val_acc: 0.9112
# Epoch 28/50
# 9600/9600 [==============================] - 4s 461us/step - loss: 0.2112 - acc: 0.9243 - val_loss: 0.3019 - val_acc: 0.9121
# Epoch 29/50
# 9600/9600 [==============================] - 4s 459us/step - loss: 0.2094 - acc: 0.9248 - val_loss: 0.2992 - val_acc: 0.9125
# Epoch 30/50
# 9600/9600 [==============================] - 5s 497us/step - loss: 0.2136 - acc: 0.9254 - val_loss: 0.2664 - val_acc: 0.9200
# Epoch 31/50
# 9600/9600 [==============================] - 4s 443us/step - loss: 0.2127 - acc: 0.9235 - val_loss: 0.2782 - val_acc: 0.9192
# Epoch 32/50
# 9600/9600 [==============================] - 4s 458us/step - loss: 0.2045 - acc: 0.9277 - val_loss: 0.2466 - val_acc: 0.9254
# Epoch 33/50
# 9600/9600 [==============================] - 4s 466us/step - loss: 0.2018 - acc: 0.9289 - val_loss: 0.2799 - val_acc: 0.9221
# Epoch 34/50
# 9600/9600 [==============================] - 5s 509us/step - loss: 0.2020 - acc: 0.9287 - val_loss: 0.2974 - val_acc: 0.9162
# Epoch 35/50
# 9600/9600 [==============================] - 5s 512us/step - loss: 0.2024 - acc: 0.9270 - val_loss: 0.2822 - val_acc: 0.9196
# Epoch 36/50
# 9600/9600 [==============================] - 5s 471us/step - loss: 0.1957 - acc: 0.9289 - val_loss: 0.2437 - val_acc: 0.9283
# Epoch 37/50
# 9600/9600 [==============================] - 4s 454us/step - loss: 0.2078 - acc: 0.9250 - val_loss: 0.2667 - val_acc: 0.9246
# Epoch 38/50
# 9600/9600 [==============================] - 4s 457us/step - loss: 0.1999 - acc: 0.9278 - val_loss: 0.2643 - val_acc: 0.9254
# Epoch 39/50
# 9600/9600 [==============================] - 4s 430us/step - loss: 0.2042 - acc: 0.9268 - val_loss: 0.2582 - val_acc: 0.9271
# Epoch 40/50
# 9600/9600 [==============================] - 4s 459us/step - loss: 0.1981 - acc: 0.9321 - val_loss: 0.2470 - val_acc: 0.9275
# Epoch 41/50
# 9600/9600 [==============================] - 4s 433us/step - loss: 0.1983 - acc: 0.9283 - val_loss: 0.2619 - val_acc: 0.9254
# Epoch 42/50
# 9600/9600 [==============================] - 4s 445us/step - loss: 0.1955 - acc: 0.9304 - val_loss: 0.2701 - val_acc: 0.9258
# Epoch 43/50
# 9600/9600 [==============================] - 4s 441us/step - loss: 0.1956 - acc: 0.9311 - val_loss: 0.2715 - val_acc: 0.9242
# Epoch 44/50
# 9600/9600 [==============================] - 5s 501us/step - loss: 0.1906 - acc: 0.9316 - val_loss: 0.2507 - val_acc: 0.9287
# Epoch 45/50
# 9600/9600 [==============================] - 4s 444us/step - loss: 0.1871 - acc: 0.9352 - val_loss: 0.2728 - val_acc: 0.9250
# Epoch 46/50
# 9600/9600 [==============================] - 4s 445us/step - loss: 0.1950 - acc: 0.9319 - val_loss: 0.2721 - val_acc: 0.9250
# Epoch 47/50
# 9600/9600 [==============================] - 4s 436us/step - loss: 0.1900 - acc: 0.9325 - val_loss: 0.2410 - val_acc: 0.9308
# Epoch 48/50
# 9600/9600 [==============================] - 5s 531us/step - loss: 0.1901 - acc: 0.9331 - val_loss: 0.2647 - val_acc: 0.9283
# Epoch 49/50
# 9600/9600 [==============================] - 5s 512us/step - loss: 0.1930 - acc: 0.9300 - val_loss: 0.2655 - val_acc: 0.9267
# Epoch 50/50
# 9600/9600 [==============================] - 4s 462us/step - loss: 0.1890 - acc: 0.9318 - val_loss: 0.2399 - val_acc: 0.9317

# %%
accuracy = train.history['acc']
val_accuracy = train.history['val_acc']
loss = train.history['loss']
val_loss = train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model.save('data/model6.hdf5')
